# %% [markdown]
# # Python walk-through
#
# This notebook will just go through the basic topics in order:
#
# * Data types
#     * Numbers
#     * Strings
#     * Printing
#     * Lists
#     * Dictionaries
#     * Booleans
#     * Tuples
#     * Sets
# * Comparison Operators
# * if, elif, else Statements
# * for Loops
# * while Loops
# * range()
# * list comprehension
# * functions
# * lambda expressions
# * map and filter
# * methods
# * Error handling

# %% [markdown]
# ## Data types
#
# ### Numbers

# %%
1 + 1
# Out:
# 2

# %%
3-4
# Out:
# -1

# %%
1 * 3
# Out:
# 3

# %%
1 / 2
# Out:
# 0.5

# %%
2 ** 4
# Out:
# 16

# %%
4 % 2 # remainder
# Out:
# 0

# %%
5 % 2
# Out:
# 1

# %%
(2 + 3) * (5 + 5)
# Out:
# 50

# %% [markdown]
# ### Variable Assignment

# %%
# Can not start with number or special characters
name_of_var = 2

# %%
x = 2
y = 3

# %% [markdown]
# ### heading

# %%
a = 10
b = 20
c = 30
print(a+b+c)
# Out:
# 60

# %%
z = x + y

# %%
z
# Out:
# 5

# %% [markdown]
# ### Strings

# %%
'single quotes'
# Out:
# 'single quotes'

# %%
"double quotes"
# Out:
# 'double quotes'

# %%
" wrap lot's of other quotes"
# Out:
# " wrap lot's of other quotes"

# %% [markdown]
# ### Printing

# %%
x = 'hello'

# %%
x
# Out:
# 'hello'

# %%
print(x)
# Out:
# hello

# %%
num = 25
name = 'Vishal'

# %%
print('My number is: {one}, and my name is: {two}'.format(one=num,two=name))
# Out:
# My number is: 25, and my name is: Utkarsh

# %%
# TODO: f strings

# %%
print('My number is: {}, and my name is: {}'.format(name,num))
# Out:
# My number is: Utkarsh, and my name is: 25

# %% [markdown]
# ### Lists

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
['hi',1,[1,2]]
# Out:
# ['hi', 1, [1, 2]]

# %%
my_list = ['a','b','c']

# %%
my_list.append('d')

# %%
my_list
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[1]
# Out:
# 'b'

# %%
my_list[1:] # Slicing
# Out:
# ['b', 'c', 'd']

# %%
my_list[:2] # Range at y is exclusive
# Out:
# ['a', 'b']

# %%
my_list[0] = 'NEW'

# %%
my_list
# Out:
# ['NEW', 'b', 'c', 'd']

# %%
nest = [1,2,3,[4,5,['target']]] # Nesting

# %%
nest[3]
# Out:
# [4, 5, ['target']]

# %%
nest[3][2]
# Out:
# ['target']

# %%
nest[3][2][0]
# Out:
# 'target'

# %%
# ToDO: var = [1,2,'d']
# var[-1]

# %% [markdown]
# ### Dictionaries

# %%
d = {'Name':'Utkarsh',
     'key2':'item2',
     'key3':34}

# %%
d
# Out:
# {'Name': 'Utkarsh', 'key2': 'item2', 'key3': 34}

# %%
d['Name']
# Out:
# 'Utkarsh'

# %% [markdown]
# ### Booleans

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %% [markdown]
# ### Tuples

# %%
t = (1,2,3)

# %%
t[0]
# Out:
# 1

# %%
t[0] = 'NEW'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-93bfe9be1549> in <cell line: 0>()
# ----> 1 t[0] = 'NEW'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Sets

# %%
{1,2,3}
# Out:
# {1, 2, 3}

# %%
{1,2,3,1,2,1,2,3,3,3,3,2,2,2,1,1,2}
# Out:
# {1, 2, 3}

# %% [markdown]
# ## Comparison Operators

# %%
1 > 2
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
1 >= 1
# Out:
# True

# %%
1 <= 4
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
1 = 1
# Out:
#   File "<ipython-input-57-ecdac3dcabfd>", line 1
#     1 = 1
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
'hi' == 'bye'
# Out:
# False

# %%
1 == '1'
# Out:
# False

# %% [markdown]
# ## Logic Operators

# %%
(1 > 2) and (2 < 3)
# Out:
# False

# %%
(1 > 2) or (2 < 3)
# Out:
# True

# %%
(1 == 2) or (2 == 3) or (4 == 4)
# Out:
# True

# %% [markdown]
# ## if,elif, else Statements

# %%
if 1 < 2:
    print('Yep!')
# Out:
# Yep!

# %%
if 1 > 2:
    print('yep!')

# %%
if 1 < 2:
    print('first')
else:
    print('last')
# Out:
# first

# %%
if 1 > 2:
    print('first')
else:
    print('last')
# Out:
# last

# %%
if 1 == 2:
    print('first')
elif 3 == 3:
    print('middle')
elif 4 == 4:
    print('last')
else:
    print('Last')
# Out:
# middle

# %% [markdown]
# ## for Loops

# %%
seq = [1,2,3,4,5]

# %%
for item in seq:
    print(item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for item in seq:
    print('Yep')
# Out:
# Yep
# Yep
# Yep
# Yep
# Yep

# %%
for jelly in seq:
    print(jelly+jelly)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ## while Loops

# %%
i = 1
while i < 5:
    print('i is: {}'.format(i))
    i = i+1
# Out:
# i is: 1
# i is: 2
# i is: 3
# i is: 4

# %% [markdown]
# ## range()

# %%
range(6)
# Out:
# range(0, 6)

# %%
for i in range(6):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# ## list comprehension

# %%
x = [1,2,3,4]

# %%
out = []
for item in x:
    out.append(item**2)
print(out)
# Out:
# [1, 4, 9, 16]

# %%
cubes = [item**3 for item in x]
cubes
# Out:
# [1, 8, 27, 64]

# %% [markdown]
# ## functions

# %%
def my_func(param1='default'):
    """
    Docstring goes here.
    """
    print(param1)

# %%
my_func
# Out:
# <function __main__.my_func(param1='default')>

# %%
my_func()
# Out:
# default

# %%
my_func('new param')
# Out:
# new param

# %%
my_func(param1='new param')
# Out:
# new param

# %%
def square(x):
    return x**2

# %%
out = square(6)

# %%
print(out)
# Out:
# 36

# %% [markdown]
# ## lambda expressions

# %%
def times2(var):
    return var*2

# %%
times2(8)
# Out:
# 16

# %%
func = lambda var: var*5

# %%
func(8)
# Out:
# 40

# %% [markdown]
# ## map and filter

# %%
seq = [1,2,3,4,5]

# %%
map(times2,seq)

# %%
list(map(times2,seq))
# Out:
# [2, 4, 6, 8, 10]

# %%
list(map(lambda var: var*5,seq))
# Out:
# [5, 10, 15, 20, 25]

# %%
filter(lambda item: item%2 == 1,seq)

# %%
list(filter(lambda item: item%2 == 1,seq))
# Out:
# [1, 3, 5]

# %% [markdown]
# ## methods

# %%
st = 'hello my name is Sam'

# %%
st.lower()
# Out:
# 'hello my name is sam'

# %%
st.upper()
# Out:
# 'HELLO MY NAME IS SAM'

# %%
st.split()
# Out:
# ['hello', 'my', 'name', 'is', 'Sam']

# %%
tweet = 'Go Sports! #Sports'

# %%
tweet.split('S')
# Out:
# ['Go ', 'ports! #', 'ports']

# %%
tweet.split('#')[1]
# Out:
# 'Sports'

# %%
d
# Out:
# {'Name': 'Utkarsh', 'key2': 'item2', 'key3': 34}

# %%
d.keys()
# Out:
# dict_keys(['Name', 'key2', 'key3'])

# %%
d.items()
# Out:
# dict_items([('Name', 'Utkarsh'), ('key2', 'item2'), ('key3', 34)])

# %%
lst = [1,2,3]

# %%
lst.pop()
# Out:
# 3

# %%
lst
# Out:
# [1, 2]

# %%
'x' in [1,2,3]
# Out:
# False

# %%
'x' in ['x','y','z']
# Out:
# True

# %% [markdown]
# # Error Handling

# %%
var=10
answer = int(input("Enter Number: "))
var/answer
# Out:
# Enter Number: sdfsdf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-f5358941f7e3> in <cell line: 0>()
#       1 var=10
# ----> 2 answer = int(input("Enter Number: "))
#       3 var/answer
#
# ValueError: invalid literal for int() with base 10: 'sdfsdf'

# %%
# code asks user for number and divides 10 by it
# enter '0' to trigger exception
# enter any string to check for exception
try:
    var=10
    answer = int(input("Enter Number: "))
    print(var/answer)
except ZeroDivisionError as e:
    print(e)
except ValueError:
    print("Caught any exception")
# Out:
# Enter Number: utksrsh
# Caught any exception

# %%
try:
    var=10
    answer = int(input("Enter Number: "))
    print(var/answer)
except ZeroDivisionError as e:
    print(e)
except ValueError:
    print("Caught any exception")
except:
    pass
finally:
    print("Exit code")
# Out:
# Enter Number: 0
# division by zero
# Exit code

# %% [markdown]
# # Great Job!
